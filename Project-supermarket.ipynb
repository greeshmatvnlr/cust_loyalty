# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
pip install matplotlib --upgrade --user
# Out:
# Requirement already up-to-date: matplotlib in c:\users\dell\appdata\roaming\python\python37\site-packages (3.5.3)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('supermarkett.csv', encoding= 'unicode_escape')

# %%
df
# Out:
#      Sl No.  Male/Female  Bill(£) Did the participants used loyalty card  \
# 0        NaN         NaN      NaN                                    NaN
# 1        1.0           F     77.0                                      Y
# 2        2.0           M     47.0                                      Y
# 3        3.0           M      7.0                                      Y
# 4        4.0           M    120.0                                      Y
# 5        5.0           M    124.0                                      Y
# 6        6.0           M      6.0                                      N
# 7        7.0           F     41.0                                      Y
# 8        8.0           M     68.0                                      Y
# 9        9.0           M     28.0                                      Y
# 10      10.0           F     60.0                                      Y
# 11      11.0           F     65.0                                      Y
# ...

# %%
df.shape
# Out:
# (101, 8)

# %%
df.head()
# Out:
#    Sl No.  Male/Female  Bill(£) Did the participants used loyalty card  \
# 0      NaN         NaN      NaN                                    NaN
# 1      1.0           F     77.0                                      Y
# 2      2.0           M     47.0                                      Y
# 3      3.0           M      7.0                                      Y
# 4      4.0           M    120.0                                      Y
#
#   Did the customer used loyalty voucher for shopping?  \
# 0                                                NaN
# 1                                                  Y
# 2                                                  Y
# 3                                                  Y
# 4                                                  Y
#
#   Did the customer purchased any item to use the loyalty voucher?  \
# 0                                                NaN
# 1                                                  N
# ...

# %%
df.tail()
# Out:
#      Sl No.  Male/Female  Bill(£) Did the participants used loyalty card  \
# 96      96.0           F     75.0                                      Y
# 97      97.0           F     67.0                                      Y
# 98      98.0           M    155.0                                      Y
# 99      99.0           M    180.0                                      Y
# 100    100.0           M    125.0                                      Y
#
#     Did the customer used loyalty voucher for shopping?  \
# 96                                                   Y
# 97                                                   N
# 98                                                   Y
# 99                                                   Y
# 100                                                  N
#
#     Did the customer purchased any item to use the loyalty voucher?  \
# 96                                                   Y
# 97                                                   N
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Sl No.  Male/Female  Bill(£) Did the participants used loyalty card  \
# 0        NaN         NaN      NaN                                    NaN
# 1        1.0           F     77.0                                      Y
# 2        2.0           M     47.0                                      Y
# 3        3.0           M      7.0                                      Y
# 4        4.0           M    120.0                                      Y
# 5        5.0           M    124.0                                      Y
# 6        6.0           M      6.0                                      N
# 7        7.0           F     41.0                                      Y
# 8        8.0           M     68.0                                      Y
# 9        9.0           M     28.0                                      Y
# 10      10.0           F     60.0                                      Y
# ...

# %%
pd.isnull(df).sum()
# Out:
# Sl No.                                                             1
# Male/Female                                                        1
# Bill(£)                                                            1
# Did the participants used loyalty card                             1
# Did the customer used loyalty voucher for shopping?                1
# Did the customer purchased any item to use the loyalty voucher?    1
# How often visit at supermarket A                                   1
# Other supermarket often visits by the customer                     1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# Sl No.                                                             0
# Male/Female                                                        0
# Bill(£)                                                            0
# Did the participants used loyalty card                             0
# Did the customer used loyalty voucher for shopping?                0
# Did the customer purchased any item to use the loyalty voucher?    0
# How often visit at supermarket A                                   0
# Other supermarket often visits by the customer                     0
# dtype: int64

# %%
df
# Out:
#      Sl No.  Male/Female  Bill(£) Did the participants used loyalty card  \
# 1        1.0           F     77.0                                      Y
# 2        2.0           M     47.0                                      Y
# 3        3.0           M      7.0                                      Y
# 4        4.0           M    120.0                                      Y
# 5        5.0           M    124.0                                      Y
# 6        6.0           M      6.0                                      N
# 7        7.0           F     41.0                                      Y
# 8        8.0           M     68.0                                      Y
# 9        9.0           M     28.0                                      Y
# 10      10.0           F     60.0                                      Y
# 11      11.0           F     65.0                                      Y
# 12      12.0           F     78.0                                      Y
# ...

# %%
df['Bill(£)'].describe()
# Out:
# count    100.000000
# mean     104.180000
# std       61.542854
# min        6.000000
# 25%       66.500000
# 50%       92.000000
# 75%      146.000000
# max      312.000000
# Name: Bill(£), dtype: float64

# %% [markdown]
# # EXPLORATORY  DATA ANALYSIS

# %%
df.columns
# Out:
# Index(['Sl No. ', 'Male/Female', 'Bill(£)',
#        'Did the participants used loyalty card',
#        'Did the customer used loyalty voucher for shopping?',
#        'Did the customer purchased any item to use the loyalty voucher?',
#        'How often visit at supermarket A',
#        'Other supermarket often visits by the customer'],
#       dtype='object')

# %% [markdown]
# # Gender

# %%
ax = sns.countplot(x = 'Male/Female',data = df)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# # Loyalty card users Vs non-users

# %%
ax = sns.countplot(x = 'Did the participants used loyalty card',data = df)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# # Loyalty voucher user Vs non-users

# %%
bx = sns.countplot(x = 'Did the customer used loyalty voucher for shopping?',data = df)
for bars in bx.containers:
    bx.bar_label(bars)

# %% [markdown]
# # Customers purchased to use the vouchers Vs non-users

# %%
cx = sns.countplot(x = 'Did the customer purchased any item to use the loyalty voucher?',data = df)
for bars in cx.containers:
    cx.bar_label(bars)

# %% [markdown]
# # How often people visit store A

# %%
dx = sns.countplot(x = 'How often visit at supermarket A',data = df)
for bars in dx.containers:
    dx.bar_label(bars)

# %% [markdown]
# # Other stores visisted by the customers of store A

# %%
ex = sns.countplot(x = 'Other supermarket often visits by the customer',data = df)
for bars in ex.containers:
    ex.bar_label(bars)

# %% [markdown]
# # Total Bill amount Vs gender

# %%
bill_gen = df.groupby(['Male/Female'], as_index=False)['Bill(£)'].sum().sort_values(by='Bill(£)', ascending=False)

fx=sns.barplot(x = 'Male/Female',y= 'Bill(£)' ,data = bill_gen)

for bars in fx.containers:
    fx.bar_label(bars)

# %% [markdown]
# # Total Bill paid by loyalty card users Vs non users

# %%
bill_loyalty = df.groupby(['Did the participants used loyalty card'], as_index=False)['Bill(£)'].sum().sort_values(by='Bill(£)', ascending=False)

gx=sns.barplot(x = 'Did the participants used loyalty card',y= 'Bill(£)' ,data = bill_loyalty)

for bars in gx.containers:
    gx.bar_label(bars)

# %% [markdown]
# # Total bill amount paid by voucher users vs non users

# %%
bill_voucher = df.groupby(['Did the customer used loyalty voucher for shopping?'], as_index=False)['Bill(£)'].sum().sort_values(by='Bill(£)', ascending=False)

hx=sns.barplot(x = 'Did the customer used loyalty voucher for shopping?',y= 'Bill(£)' ,data = bill_voucher)

for bars in hx.containers:
    hx.bar_label(bars)

# %%
bill_voucher_for_item = df.groupby(['Did the customer purchased any item to use the loyalty voucher?'], as_index=False)['Bill(£)'].sum().sort_values(by='Bill(£)', ascending=False)

ix=sns.barplot(x = 'Did the customer purchased any item to use the loyalty voucher?',y= 'Bill(£)' ,data = bill_voucher_for_item)

for bars in ix.containers:
    ix.bar_label(bars)

# %%
#Bill amount Vs how often people visits the store

# %%
bill_visit = df.groupby(['How often visit at supermarket A'], as_index=False)['Bill(£)'].sum().sort_values(by='Bill(£)', ascending=False)

jx=sns.barplot(x = 'How often visit at supermarket A',y= 'Bill(£)' ,data = bill_visit)

for bars in jx.containers:
    jx.bar_label(bars)

# %%
#customers visit vs loyalty card vs bill abount

# %%
Loyalty_visit = df.groupby(['How often visit at supermarket A', 'Did the participants used loyalty card'], as_index=False)['Bill(£)'].sum().sort_values(by='Bill(£)', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = Loyalty_visit, x = 'How often visit at supermarket A',y= 'Bill(£)', hue='Did the participants used loyalty card')
# Out:
# <AxesSubplot:xlabel='How often visit at supermarket A', ylabel='Bill(£)'>

# %%
#customer visit vs voucher users vs bill amount

# %%
voucher_visit = df.groupby(['How often visit at supermarket A', 'Did the customer used loyalty voucher for shopping?'], as_index=False)['Bill(£)'].sum().sort_values(by='Bill(£)', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = voucher_visit, x = 'How often visit at supermarket A',y= 'Bill(£)', hue='Did the customer used loyalty voucher for shopping?')
# Out:
# <AxesSubplot:xlabel='How often visit at supermarket A', ylabel='Bill(£)'>
